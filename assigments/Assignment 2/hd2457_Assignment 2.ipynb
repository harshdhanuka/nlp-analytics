# %% [markdown]
# ### APANPS 5430: Applied Text and Natural Language Analytics, Fall 2020
#
# ## Assignment 2: JSON Objects
#
# Submitted by -
# #### Harsh Dhanuka, hd2457

# %%
import pandas as pd
import numpy as np
import json
from pprint import pprint

from io import StringIO
from pandas_schema import Column, Schema

pd.set_option('display.max_rows', 150)
pd.set_option('display.max_columns', 20)
pd.set_option('display.width', 1000)

# %% [markdown]
# # 1. Reads JSON newsfeeds from the data file into a Python array of dictionaries or a Pandas dataframe

# %% [markdown]
# ### I am using the `Netflix` data for my assignment

# %%
# Read the JSON file as array dictionary

file = '/Users/harshdhanuka/Desktop/Columbia Class Matter/SEM 3/5430 Applied Text NLP/Assignment 2/webhose_netflix.json'

json_data=open(file).readlines()
newsfeeds = []

for line in json_data:
    newsfeeds.append(json.loads(line))

# %%
# Convert it to Pandas dataframe

df = pd.DataFrame.from_dict(newsfeeds)

# %%
# Check the basic column/feature types

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25288 entries, 0 to 25287
# Data columns (total 18 columns):
# thread                  25288 non-null object
# uuid                    25288 non-null object
# url                     25288 non-null object
# ord_in_thread           25288 non-null int64
# parent_url              0 non-null object
# author                  25288 non-null object
# published               25288 non-null object
# title                   25288 non-null object
# text                    25288 non-null object
# highlightText           25288 non-null object
# highlightTitle          25288 non-null object
# highlightThreadTitle    25288 non-null object
# language                25288 non-null object
# external_links          25288 non-null object
# external_images         25288 non-null object
# entities                25288 non-null object
# rating                  0 non-null object
# crawled                 25288 non-null object
# dtypes: int64(1), object(17)
# memory usage: 3.5+ MB

# %%
# Check the 1st column

df.head(1)
# Out:
#                                               thread                                      uuid                                                url  ord_in_thread parent_url       author                      published                                              title                                               text highlightText highlightTitle highlightThreadTitle language external_links external_images                                           entities rating                        crawled
# 0  {'uuid': 'f890670c1406310226c8e9420a798d81420c...  f890670c1406310226c8e9420a798d81420c5a96  http://omgili.com/ri/.wHSUbtEfZSCvFgWhG.N__Y_k...              0       None  stuff.co.nz  2020-06-03T22:49:00.000+03:00  13 Reasons Why: The popular Netflix show's cre...  The controversial 13 Reasons Why is returning ...                                                    english             []              []  {'persons': [{'name': 'hannah baker', 'sentime...   None  2020-06-03T05:55:53.024+03:00

# %% [markdown]
# ### Convert the `published` column to appropriate format

# %%
df['published'] =  pd.to_datetime(df['published'])

# %% [markdown]
# #### Seems like the 1st column `thread` and the `uuid` are the same values.

# %% [markdown]
# # 2. Prints the schema of the JSON object

# %%
print(" ")
print("The schema of the JSON object is as follows:")
print(" ")
pd.io.json.build_table_schema(data = df)
# Out:
#
# The schema of the JSON object is as follows:
# {'fields': [{'name': 'index', 'type': 'integer'},
#   {'name': 'thread', 'type': 'string'},
#   {'name': 'uuid', 'type': 'string'},
#   {'name': 'url', 'type': 'string'},
#   {'name': 'ord_in_thread', 'type': 'integer'},
#   {'name': 'parent_url', 'type': 'string'},
#   {'name': 'author', 'type': 'string'},
#   {'name': 'published', 'type': 'datetime', 'tz': None},
#   {'name': 'title', 'type': 'string'},
#   {'name': 'text', 'type': 'string'},
#   {'name': 'highlightText', 'type': 'string'},
#   {'name': 'highlightTitle', 'type': 'string'},
#   {'name': 'highlightThreadTitle', 'type': 'string'},
#   {'name': 'language', 'type': 'string'},
#   {'name': 'external_links', 'type': 'string'},
#   {'name': 'external_images', 'type': 'string'},
#   {'name': 'entities', 'type': 'string'},
#   {'name': 'rating', 'type': 'string'},
#   {'name': 'crawled', 'type': 'string'}],
#  'primaryKey': ['index'],
#  'pandas_version': '0.20.0'}

# %% [markdown]
# #### Almost all of the variables are in 'string' format, except a few which are integer.

# %% [markdown]
# ## 3. Prints the number of newsfeeds (JSON objects) in the collection

# %%
print(" ")
print("There are ",df.shape[0]," rows/number of newsfeeds in the JSON object file")
print(" ")
print("There are ",df.shape[1]," columns/number of variables in the JSON object file")
print(" ")
# Out:
#
# There are  25288  rows/number of newsfeeds in the JSON object file
#
# There are  18  columns/number of variables in the JSON object file

# %%
# Verify

df.shape
# Out:
# (25288, 18)

# %% [markdown]
# # 4. Creates a set of unique newsfeeds by `title` and prints the new total collection size

# %%
# Remove duplicate entries, and make a subset based on 'title'

df = df.drop_duplicates(subset = 'title', keep = 'last', inplace = False)

# keep = Last as I need to keep the latest entries.

# %%
# Check the new data set

df.head(1)
# Out:
#                                               thread                                      uuid                                                url  ord_in_thread parent_url       author                 published                                              title                                               text highlightText highlightTitle highlightThreadTitle language external_links external_images                                           entities rating                        crawled
# 0  {'uuid': 'f890670c1406310226c8e9420a798d81420c...  f890670c1406310226c8e9420a798d81420c5a96  http://omgili.com/ri/.wHSUbtEfZSCvFgWhG.N__Y_k...              0       None  stuff.co.nz 2020-06-03 22:49:00+03:00  13 Reasons Why: The popular Netflix show's cre...  The controversial 13 Reasons Why is returning ...                                                    english             []              []  {'persons': [{'name': 'hannah baker', 'sentime...   None  2020-06-03T05:55:53.024+03:00

# %%
print(" ")
print("There are ",df.shape[0]," 'unique' rows/number of newsfeeds/collections in the JSON object file")
print(" ")
print("There are ",df.shape[1]," columns/number of variables in the JSON object file")
print(" ")
# Out:
#
# There are  19514  'unique' rows/number of newsfeeds/collections in the JSON object file
#
# There are  18  columns/number of variables in the JSON object file

# %%
# Verify

df.shape
# Out:
# (19514, 18)

# %% [markdown]
# # 5. Prints the latest 100 article titles, urls, and publish dates

# %%
# Sort by the 'published date' column

df = df.sort_values(by = 'published', ascending = False)

# %%
# Create a new df with only the 3 required columns

df2 = df[['title', 'url', 'published']].copy()
df2.head(100)

# I am printing the first 100 rows as required.
# Out:
#                                                  title                                                url                 published
# 0    13 Reasons Why: The popular Netflix show's cre...  http://omgili.com/ri/.wHSUbtEfZSCvFgWhG.N__Y_k... 2020-06-03 22:49:00+03:00
# 2    A TV reboot of Bong Joon-ho's acclaimed film S...  http://omgili.com/ri/.wHSUbtEfZSvmJKugzHb_f4zA... 2020-06-03 07:33:00+03:00
# 3    2-Pack: Ideaworks Mosquito Killer Lamps (batte...  http://omgili.com/ri/.wHSUbtEfZTqX_2tXJqGoKlaY... 2020-06-03 07:00:00+03:00
# 4    Already-Obese Average Americans Have Drunk & E...  http://omgili.com/ri/.0rSU5LtMgwxhVu4uw52IUGPG... 2020-06-03 06:45:00+03:00
# 5    Netflix, Disney join other big brands in suppo...  http://omgili.com/ri/.wHSUbtEfZThiio0hiTRCuDRH... 2020-06-03 06:39:00+03:00
# 6    Novel Entertainment's First Animated Feature-L...  http://omgili.com/ri/.wHSUbtEfZSKGAN5cNsgLsyo0... 2020-06-03 06:06:00+03:00
# 7    Anime Based On Best-Selling 1973 Disaster Nove...  http://omgili.com/ri/.wHSUbtEfZQWtoCKOsZc0dhs0... 2020-06-03 05:58:00+03:00
# 8    Tiger King star Carole Baskin’s dead husband’s...  http://omgili.com/ri/.wHSUbtEfZQD1RVKFqxhqwVEB... 2020-06-03 05:57:00+03:00
# 9    All about Netflix’s sci-fi television shows we...  http://omgili.com/ri/.wHSUbtEfZRrqAH1UjXSpXrco... 2020-06-03 05:42:00+03:00
# 10                 File:Federation starbase, 2230s.png  http://omgili.com/ri/.wHSUbtEfZQzgU.BYEgsHJEur... 2020-06-03 05:30:00+03:00
# 11   news: Reemerged documentary reveals reason beh...  http://omgili.com/ri/.wHSUbtEfZQ5KwN3j6K0SaRVt... 2020-06-03 05:28:00+03:00
# 12   Samsung TV Plus Launches LGBTQ+ Streaming Netw...  http://omgili.com/ri/.wHSUbtEfZQvB0Ren7pZibxKw... 2020-06-03 05:09:00+03:00
# 13   US Says Will Investigate India, Other Nations ...  http://omgili.com/ri/jHIAmI4hxg9p_UOqC.BTRToTM... 2020-06-03 05:07:00+03:00
# 14   COMPACT PRO G3 | GAMING NATIVE HD SMART ANDROI...  http://omgili.com/ri/.wHSUbtEfZRsKhd3t2BKyuMUq... 2020-06-03 04:56:00+03:00
# 15   Even with Masterchef, programming more desert ...  http://omgili.com/ri/.wHSUbtEfZQnx.pKprvuwbg69... 2020-06-03 04:28:00+03:00
# 16   Who Is Abigail Koppel? Everything To Know Abou...  http://omgili.com/ri/.wHSUbtEfZRQ8TTpGdBoLB36f... 2020-06-03 04:15:00+03:00
# 17   Egypt- Legendary director Youssef Chahine's fi...  http://omgili.com/ri/.wHSUbtEfZRYvNcn2RnUd8hVl... 2020-06-03 04:12:00+03:00
# 18   “Hollywood” Gives 1940s Movie History an Inter...  http://omgili.com/ri/.wHSUbtEfZT2o9n_qqxW779oC... 2020-06-03 04:02:00+03:00
# 20       Viz Media Brings ‘Megalobox’ Anime To Netflix  http://omgili.com/ri/.wHSUbtEfZRKlAOjaY1hqXKv.... 2020-06-03 04:00:00+03:00
# 21     Now that you have reached the end of Netflix...  http://omgili.com/ri/.wHSUbtEfZRns.wRzPAduw6fO... 2020-06-03 03:56:00+03:00
# 22   Facebook and Twitter need more Peter Thiel and...  http://omgili.com/ri/.wHSUbtEfZQwU97HLU2a0.qaf... 2020-06-03 03:55:00+03:00
# 23       Companies back ‘black lives  matter’ campaign  http://omgili.com/ri/.wHSUbtEfZRiDpHw2pFua177X... 2020-06-03 03:50:00+03:00
# 25   LG 50" Class 4K UHD 2160P Smart TV 50UN6950ZUF...  http://omgili.com/ri/.wHSUbtEfZSCskm_gl44z4jqE... 2020-06-03 03:36:00+03:00
# 26   Walmart refuses to sell film on threat to free...  http://omgili.com/ri/.wHSUbtEfZRUj3Dq8TgVCKSqt... 2020-06-03 03:21:00+03:00
# 27   The will of 'Tiger King' star Carole Baskin's ...  http://omgili.com/ri/.wHSUbtEfZSmdQCdG.r1hbDzk... 2020-06-03 03:15:00+03:00
# 28   'Black Lives Matter:' Netflix, HBO, and Amazon...  http://omgili.com/ri/.wHSUbtEfZT93nQ_4cToN1asc... 2020-06-03 03:12:00+03:00
# 30   The 9 best Showtime series you can watch right...  http://omgili.com/ri/.wHSUbtEfZRx.QesslmhJgMYA... 2020-06-03 03:02:00+03:00
# 37   Countdown to the Captain’s ‘Crash Landing’ | P...  http://omgili.com/ri/.wHSUbtEfZQzFyRu04K8_621W... 2020-06-03 03:00:00+03:00
# 42   George Floyd death: Netflix, WarnerMedia, Ford...  http://omgili.com/ri/.wHSUbtEfZRrQMwA9kyMdECN6... 2020-06-03 03:00:00+03:00
# 40   Ownership of Joe Exotic's zoo given to rival C...  http://omgili.com/ri/.wHSUbtEfZRZ6Yu_8AIJ0wdzu... 2020-06-03 03:00:00+03:00
# 38   Choked is Anurag Kashyap's Most Accessible Fil...  http://omgili.com/ri/.wHSUbtEfZSSzgR2UrK0iUGzF... 2020-06-03 03:00:00+03:00
# 33   "SAL VELEZ JR." The Baka Boyz Show on The City...  http://omgili.com/ri/.wHSUbtEfZTsnrROA5kwRRmmV... 2020-06-03 03:00:00+03:00
# 36   Judge Gives Carole Baskin the Tiger King’s Zoo...  http://omgili.com/ri/.wHSUbtEfZRnUVQFzL6ufb0Qn... 2020-06-03 03:00:00+03:00
# 35   UnitedHeath Group, YouTube, Airbnb, Lyft Respo...  http://omgili.com/ri/.wHSUbtEfZSXJy8QueI_F.rgD... 2020-06-03 03:00:00+03:00
# 34   BBC’s own Beeb voice assistant enters beta trials  http://omgili.com/ri/.wHSUbtEfZRh5.iGfYdzc9xTK... 2020-06-03 03:00:00+03:00
# 32   'Tiger King' star loses animal park to nemesis...  http://omgili.com/ri/.wHSUbtEfZQxX.eoYWnkJDPDo... 2020-06-03 03:00:00+03:00
# 43   Steve Martin and Martin Short have rescheduled...  http://omgili.com/ri/.wHSUbtEfZTiK8pf51MwdFFZO... 2020-06-03 03:00:00+03:00
# 44   DIVERSITY IN FILMMAKING VIRTUAL PANEL 3 RECAP:...  http://omgili.com/ri/vkc1Z8ITDMtq_o1SuVRHBlGH0... 2020-06-03 02:57:00+03:00
# 45      Out Now: adidas Originals x Angel Chen Ozweego  http://omgili.com/ri/7aBdisT0NOqNKUu70vMWSYhOK... 2020-06-03 02:47:00+03:00
# 47                         New: The 'Netflix for Jews'  http://omgili.com/ri/.wHSUbtEfZRK2exrfIXZJMLbU... 2020-06-03 02:36:00+03:00
# 48   ‘13 Reasons Why,’ ‘The Twilight Zone,’ ‘El Pre...  http://omgili.com/ri/.wHSUbtEfZT93nQ_4cToN1asc... 2020-06-03 02:34:00+03:00
# 50   What Should We Expect From Entertainment Compa...  http://omgili.com/ri/.wHSUbtEfZQdMlTohNEFLFxeS... 2020-06-03 02:21:00+03:00
# 51   PeĂ§a portuguesa que viria festival pode ser v...  http://omgili.com/ri/.wHSUbtEfZQcJiaUPDVDZqeAN... 2020-06-03 02:15:00+03:00
# 53   Pinpoint Asset Management Ltd Acquires Shares ...  http://omgili.com/ri/.wHSUbtEfZQhFfIFwbDJG1gzb... 2020-06-03 02:12:00+03:00
# 54   Fascinating study reveals which country has th...  http://omgili.com/ri/.wHSUbtEfZTU5V.PWLzbcUHT6... 2020-06-03 02:05:00+03:00
# 55   Review: We’re Here Offers a Queen’s Eye View o...  http://omgili.com/ri/.wHSUbtEfZR5eYlI.UlKit356... 2020-06-03 02:00:00+03:00
# 57   US To "Investigate" India, 9 Other Nations Ove...  http://omgili.com/ri/.wHSUbtEfZRT8mhACjDa0WCDA... 2020-06-03 01:44:00+03:00
# 58   Netflix, Inc. (NASDAQ:NFLX) Shares Sold by Tor...  http://omgili.com/ri/.wHSUbtEfZQ5vy3q3jf4pUXuk... 2020-06-03 01:34:00+03:00
# 59   How brands are managing social media while Ins...  http://omgili.com/ri/.wHSUbtEfZQU1NAlLgG2rBoML... 2020-06-03 01:29:00+03:00
# 60      Judge awards the zoo in Netflix’s ‘Tiger King’  http://omgili.com/ri/.wHSUbtEfZRYvNcn2RnUd8hVl... 2020-06-03 01:22:00+03:00
# 61   Fuller House: Season Six? Has the Netflix Seri...  http://omgili.com/ri/.wHSUbtEfZT4U4IqP2SHMMSBZ... 2020-06-03 01:17:00+03:00
# 62     AT&T defends HBO Max’s exclusion from data caps  http://omgili.com/ri/.wHSUbtEfZSnvpgZrQVM7DEOI... 2020-06-03 01:16:00+03:00
# 63   Good One Podcast: Hannah Gadsby on Douglas, Na...  http://omgili.com/ri/.wHSUbtEfZTADvHmkdnt2XlbB... 2020-06-03 01:13:00+03:00
# 64   13 Reasons Why you should check to out Netflix...  http://omgili.com/ri/.wHSUbtEfZSCvFgWhG.N__Y_k... 2020-06-03 01:10:00+03:00
# 65             Cook Off’s Netflix premiere awes Zimbos  http://omgili.com/ri/.wHSUbtEfZREJ0xl3Nto8OebN... 2020-06-03 01:05:00+03:00
# 68   Review: Briarpatch, Latest TV News - The New P...  http://omgili.com/ri/.wHSUbtEfZRVvTBJJtOsvqq32... 2020-06-03 01:00:00+03:00
# 66   Review: Central Park, Latest TV News - The New...  http://omgili.com/ri/.wHSUbtEfZRVvTBJJtOsvqq32... 2020-06-03 01:00:00+03:00
# 67   Spelling the Dream gives spotlight to Indian A...  http://omgili.com/ri/.wHSUbtEfZQvYxQFuDfpPkr6r... 2020-06-03 01:00:00+03:00
# 71   Carole Baskin awarded zoo of 'Tiger King' Joe ...  http://omgili.com/ri/.wHSUbtEfZQi9gXn_bDGqYir_... 2020-06-03 00:48:00+03:00
# 74   When is I Am Not Okay With This season 2 relea...  http://omgili.com/ri/.wHSUbtEfZQD1RVKFqxhqwVEB... 2020-06-03 00:31:00+03:00
# 75   8 States And D.C. Hold Primary Elections Amid ...  http://omgili.com/ri/.wHSUbtEfZT3wNSv7XMZzgbTJ... 2020-06-03 00:31:00+03:00
# 76     What It Is Like To Be Back To The Movie Theater  http://omgili.com/ri/.wHSUbtEfZT3wNSv7XMZzgbTJ... 2020-06-03 00:31:00+03:00
# 77   Chinese Communist Party Uses Scenes Of Violent...  http://omgili.com/ri/.wHSUbtEfZT3wNSv7XMZzgbTJ... 2020-06-03 00:31:00+03:00
# 78   Composer Will Bates (‘Hillary,’ ‘Unbelievable’...  http://omgili.com/ri/.wHSUbtEfZSUPVr_hEglFWmKJ... 2020-06-03 00:30:00+03:00
# 79   Queen of the South season 4 ending explained: ...  http://omgili.com/ri/.wHSUbtEfZQ5KwN3j6K0SaRVt... 2020-06-03 00:30:00+03:00
# 80   The real reason The Last Airbender never got a...  http://omgili.com/ri/.wHSUbtEfZTiiBdaHeIciVuXe... 2020-06-03 00:28:00+03:00
# 81   The underrated Adam Sandler movie burning up t...  http://omgili.com/ri/.wHSUbtEfZTiiBdaHeIciVuXe... 2020-06-03 00:25:00+03:00
# 83   Hey, Where's Aunt Becky? Fuller House Has an A...  http://omgili.com/ri/.wHSUbtEfZQjxv7_rD5vI0InX... 2020-06-03 00:23:00+03:00
# 85   Netflix, Inc. (NASDAQ:NFLX) Shares Bought by S...  http://omgili.com/ri/.wHSUbtEfZQ5vy3q3jf4pUXuk... 2020-06-03 00:20:00+03:00
# 86            Netflix is Adding Over 50 Movies in June  http://omgili.com/ri/.wHSUbtEfZRxQQCTSfmz1k0PH... 2020-06-03 00:19:00+03:00
# 87   Jeffrey Epstein: Filthy Rich - Ghislaine Maxwe...  http://omgili.com/ri/.wHSUbtEfZSCvFgWhG.N__Y_k... 2020-06-02 23:54:00+03:00
# 90   OnePlus 8 Pro unable to play Netflix in HD qua...  http://omgili.com/ri/.wHSUbtEfZTbjxh_usrrQXCwn... 2020-06-02 23:50:00+03:00
# 91   Carole Baskin awarded zoo of 'Tiger King' Joe ...  http://omgili.com/ri/.wHSUbtEfZTUQLZqxBnUaRkDP... 2020-06-02 23:48:00+03:00
# 92              Fuller House: Season Five Viewer Votes  http://omgili.com/ri/.wHSUbtEfZT4U4IqP2SHMMSBZ... 2020-06-02 23:42:00+03:00
# 93   Seth Rogen is telling 'All Lives Matter' comme...  http://omgili.com/ri/.wHSUbtEfZRIJjsdZnWKQK7sK... 2020-06-02 23:39:00+03:00
# 94             Our Sony Xperia 1 II video review is up  http://omgili.com/ri/.wHSUbtEfZRJ1SqriX_mz9uje... 2020-06-02 23:39:00+03:00
# 95      Carole Baskin Wins Control of ‘Tiger King’ Joe  http://omgili.com/ri/.wHSUbtEfZRYvNcn2RnUd8hVl... 2020-06-02 23:38:00+03:00
# 96               6 TV Shows Like Insecure You Must See  http://omgili.com/ri/.wHSUbtEfZTdo6KxL_vskvOCb... 2020-06-02 23:30:00+03:00
# 119  DreamWorks and Netflix present the final seaso...  http://omgili.com/ri/.wHSUbtEfZShuqU8OSon19N.X... 2020-06-02 23:17:00+03:00
# 120  "Tiger King's" Carole Baskin Awarded Joe Exoti...  http://omgili.com/ri/.wHSUbtEfZRULI3Cl7YN6_edc... 2020-06-02 23:14:00+03:00
# 121  JustInvest LLC Acquires New Holdings in Netfli...  http://omgili.com/ri/.wHSUbtEfZSy4qOhiG8rjyI6o... 2020-06-02 23:12:00+03:00
# 122  JustInvest LLC Invests $733,000 in Netflix, In...  http://omgili.com/ri/.wHSUbtEfZQd7fFNkO3aZ39i_... 2020-06-02 23:12:00+03:00
# 123  ✅ 150K MIX HQ MAIL ACCESS✨[MyCanal,Netflix,SFR...  http://omgili.com/ri/.wHSUbtEfZSstwaO1cbxDVWhH... 2020-06-02 23:10:00+03:00
# 124      Carole Baskin awarded Joe Exotic's former zoo  http://omgili.com/ri/.wHSUbtEfZRYvNcn2RnUd8hVl... 2020-06-02 23:09:00+03:00
# 139  Here's where all of the main characters end up...  http://omgili.com/ri/.wHSUbtEfZRIJjsdZnWKQK7sK... 2020-06-02 23:05:00+03:00
# 140  Novel Entertainment’s ‘Horrid Henry’ Special A...  http://omgili.com/ri/jHIAmI4hxg_dOvbX6dAs29C1n... 2020-06-02 23:02:00+03:00
# 141  Streaming HBO Max won’t count against your AT&...  http://omgili.com/ri/.wHSUbtEfZRFxmM.WvLouRptT... 2020-06-02 23:01:00+03:00
# 142  Samantha Ware Calls Out Lea Michele's Performa...  http://omgili.com/ri/.wHSUbtEfZSn361IEGObrQKVS... 2020-06-02 23:00:00+03:00
# 143  Fuller House Mentions Lori Loughlin's Characte...  http://omgili.com/ri/.wHSUbtEfZRQMgT413mwOg916... 2020-06-02 22:57:00+03:00
# 145  Netflix’s ‘Space Force’ Top Rising Show, CW’s ...  http://omgili.com/ri/.wHSUbtEfZSXJy8QueI_F1YRu... 2020-06-02 22:55:00+03:00
# 144             Selling Sunset: Who is Davina Potratz?  http://omgili.com/ri/.wHSUbtEfZQ5KwN3j6K0SaRVt... 2020-06-02 22:55:00+03:00
# 150  The 5 most anticipated TV shows returning in J...  http://omgili.com/ri/.wHSUbtEfZT1sa2cpLGZNO8D6... 2020-06-02 22:43:00+03:00
# 151  Netflix releases censored version of Vikings i...  http://omgili.com/ri/.wHSUbtEfZTLz5ZDsqTjDNQ1y... 2020-06-02 22:43:00+03:00
# 152  Netflix: Best TV and movies streaming in June ...  http://omgili.com/ri/.wHSUbtEfZRj2zBbblOpDMyw6... 2020-06-02 22:41:00+03:00
# 154  WT Wealth Management Boosts Stake in Netflix, ...  http://omgili.com/ri/.wHSUbtEfZSK45a0JjMsaPjMR... 2020-06-02 22:36:00+03:00
# 156                            Stream It – True Crime!  http://omgili.com/ri/.wHSUbtEfZQZ5Lhj8iyQDmJC8... 2020-06-02 22:36:00+03:00
# 157  Narcos Mexico: What do the real-life figures t...  http://omgili.com/ri/.wHSUbtEfZQ5KwN3j6K0SaRVt... 2020-06-02 22:32:00+03:00
# 158  Why Police and Soldiers Love Frank Castle and ...  http://omgili.com/ri/.wHSUbtEfZTADvHmkdnt2XlbB... 2020-06-02 22:28:00+03:00
# 160                                       American Pie  http://omgili.com/ri/.wHSUbtEfZThiio0hiTRCuDRH... 2020-06-02 22:24:00+03:00
# 162         Marketers are embracing Black Lives Matter  http://omgili.com/ri/.wHSUbtEfZQRfU.5KUm1RqPpL... 2020-06-02 22:17:00+03:00
